# %% [markdown]
# #                                                 **Introduction to Computing with Python**
# ![image.png](attachment:b1a3ad77-8a0b-4f48-9673-42b024895903.png)

# %% [markdown]
# What is computing or rather if we be more specific what are computers?
# The simple answer to the question is that computers are just machines. They do what they are told to do. We specify them that what they need to do. If you say computers are more intelligent than us, probably you are correct. This has been a long debatable question going since a long time.
# The answer lies within the frame of reference you are thinking. Yeah! that is not physics’ frame of reference. It is just that they are fast, efficient, disciplined in a way, unprovocative, non-humane and of course emotionless. They cannot speak unless we instruct them to. They cannot calculate unless we instruct them to. They are the machines and we humans are the masters and it will be good if it stays the way it is unless otherwise the results can be thought provoking.
# So, the simplest way to say, computers are dumb.

# %% [markdown]
# They are dumb does not mean they cannot speak. Of course, they can speak and tell you the mistakes you are making, but it is just in their way. It is because they do not know our language. It’s hard for them to know our language. Well, in a way it is hard for us to teach them our language.
#
# But we can surely learn their language. Oh, it is easy, just 0s and 1s. But rather than memorizing and writing down numbers we have languages called Programming languages. The world has seen a great deal of languages so far. I am going to use **Python**.
#
# No, it is not a snake, its name is derived from "Monty the Python" comic. Funny right? It will be very clear soon that it is as easy as funny as it sounds. It is quite helpful to us because it helps us interprets our language to computer and computer's language to ours. Simple as that! That is why it is also called interpreted language, Unlike C/C++ which are compiled languages.
#
# Sometimes Python will tell you something that you will be confused with. Those will be errors. Errors are simply not displayed because Python is angry with you. NO! It is because as I said earlier, computers are dumb. Even though you are telling something it just does not understand or has no meaning in its language. But the error can be both beautiful and irritating at the same time.  There is different type of errors:
#
# *  **Syntax errors:** During the syntax analysis phase, this type of error appears. Syntax error is found during the execution of the program. Some syntax error can be:
#     * Error in structure
#     * Missing operators
#     * Unbalanced parenthesis
#
#
# *  **Syntactic errors:** During writing code if we write down something that we meant but the computer understandss otherwise.
#
# *  **Runtime errors:** A runtime error is a program error that occurs while the program is running. The term is often used in contrast to other types of program errors, such as syntax errors and compile time errors. There are many different types of runtime errors. One example is a logic error, which produces the wrong output.
#
# And the list continues.
#
# * **Tracing**
#
#   * **Informal trace:** Traceing effective way to keep track of the values associated with variables is to use a table like the one at right, with one line giving the values after each statement has been executed. Such a table is called a trace.
#
#   *  **Object-level trace:** For a more complete understanding, we sometimes keep track of objects and references in traces. The object-level trace at right illustrates the full effect of our three assignment statements:TraceFormalThe statement a = 1234 creates an int object whose value is 1234; it then binds the variable a to this new int object.The statement b = 99 creates an int object whose value is 99; it then binds the variable b to this new int object.The statement c = a + b creates the int object whose value is 1333 as the sum of the value of the int object bound to a and the value of the int object bound to b; it then binds the variable c to the new int object.
#
# **Informal Trace :** ![image.png](attachment:5095be18-a562-4c96-9dfc-d7caa8fbdae7.png)
#
# **Object Level :** ![image.png](attachment:64bcdb67-ea5a-4e5b-be37-ce10b9800342.png)

# %% [markdown]
# ## Language of Computers: 0s and 1s
# As I have alreday mentioned that the lanuage of computers are just 0s and 1s. So need need to know how we can incorporate them and understand their language and convert to ours.
#
# If we talk about numbers then , there are many methods or techniques which can be used to convert numbers from one base to another.  Following are the conversions that can be performed. We are going to review only a few.
# * Decimal to Other Base System
# * Other Base System to Decimal
# * Other Base System to Non-Decimal
# * Shortcut method - Binary to Octal
# * Shortcut method - Octal to Binary
# * Shortcut method - Binary to Hexadecimal
# * Shortcut method - Hexadecimal to Binary

# %% [markdown]
# #### Decimal to Other Base System
# Step 1 − Divide the decimal number to be converted by the value of the new base.
#
# Step 2 − Get the remainder from Step 1 as the rightmost digit (least significant digit) of the new base number.
#
# Step 3 − Divide the quotient of the previous divide by the new base.
#
# Step 4 − Record the remainder from Step 3 as the next digit (to the left) of the new base number.
#
# Repeat Steps 3 and 4, getting remainders from right to left, until the quotient becomes zero in Step 3.
#
# The last remainder thus obtained will be the Most Significant Digit (MSD) of the new base number.
#
# Example:
#
# ![image.png](attachment:b96dd2c9-f78c-4238-af55-cd30f88ecb29.png)
#
# As mentioned in Steps 2 and 4, the remainders have to be arranged in the reverse order so that the first remainder becomes the Least Significant Digit (LSD) and the last remainder becomes the Most Significant Digit (MSD).
#
# **Decimal Number : 29 = Binary Number : 11101.**

# %% [markdown]
# #### Other Base System to Decimal System
# Step 1 − Determine the column (positional) value of each digit (this depends on the position of the digit and the base of the number system).
#
# Step 2 − Multiply the obtained column values (in Step 1) by the digits in the corresponding columns.
#
# Step 3 − Sum the products calculated in Step 2. The total is the equivalent value in decimal.
#
# Example:
#
# ![image.png](attachment:bed23581-1d86-49e2-9b5d-ac9023d6375f.png)
#
# **Binary Number : 11101 = Decimal Number : 29**

# %% [markdown]
# #### 0s & 1s Completment
#
# * **1’s complement** of a binary number is another binary number obtained by toggling all bits in it, i.e., transforming the 0 bit     to 1 and the 1 bit to 0. Let numbers be stored using 4 bits
#   * 1's complement of 7 (0111) is 8 (1000)
#   * 1's complement of 12 (1100) is 3 (0011)
#
#
# * **2’s complement** of a binary number is 1 added to the 1’s complement of the binary number.Let numbers be stored using 4 bits
#   * 2's complement of 7 (0111) is 9 (1001)
#   * 2's complement of 12 (1100) is 4 (0100)

# %% [markdown]
# # The World of Python
# Python is a open source software and can be downloaded freely. It is avavilable freely for developent and well as usage. The world owes its thanks to  **Guido Van Russom**, the creator of the beautiful language. The download link can be found here in the [Link](https://www.python.org/). It is not just the way Python is designed or how fluid, fast it is. It has a huge base of developers, community of helpers so called [Stack Overflow](https://stackoverflow.com/) and uncountable number of packages that ranges forom software development, to web development, to game development and finanlly the field we are going to explore, **DATA SCIENCE** or perhaps a branch of it called *Business Analytics*.

# %% [markdown]
# ## Installation Steps
# * Step 1: Check if Python is already avail in your system.
#
#     C:\Users\shank>Python --version
#     Python 3.8.5
#
# * Step 2: If not available download it from the website given in the [Link](python.org)
#
# * Step 3: Download Python
# ![image.png](attachment:b829c711-8a94-4042-9a4c-be03950c378b.png)
#
# * Step 4: Open Python Installer
#     * You will be promted to install python from in the path like in the below scree. Its good to have it in the path because later if you want to open python from your PC commpand promt it will be a piece of cake.
#
#         ![image.png](attachment:fca43c0e-564d-4e76-a739-a8d335bafb59.png)

# %% [markdown]
# This is just Python getting installed on your system. That is the interpreter. Now all we need is a good editor to begin our journey. The best one is always the [Anaconda](https://www.anaconda.com/products/individual). Here we have many versions of Anaconda but we will be using the **Individual Edition**.
#
# # Installing Anaconda
# * Step 1: Downlaod Anaconda
#
# * Step 2: Start the Installer
#
# * Step 3: Choose whether to add Anaconda to your PATH environment variable. We recommend not adding Anaconda to the PATH environment variable, since this can interfere with other software. Instead, use Anaconda software by opening Anaconda Navigator or the Anaconda Prompt from the Start Menu.
#
# * Step 4: Successfull Installation!
#
# * Step 5: Open Anaconda Navigator: The sNavigator screen looks just like the following image.
# ![image.png](attachment:a3cb3c34-4a0b-49b2-8ab6-a7090a286c2e.png)

# %% [markdown]
# The good news is the navigator comes with great sets of tools starting from Spyder, JupyterLab, Notebook, RStudio Integration and waht not, including python libraries that you can install very easily.
#
# *We will be using JupyterLab for our learnings. I like the interface better than Notebook. No other reason!*

# %% [markdown]
# The next big thing we need to know is **Shell** and **Script**.
#
# **Script** is a place where you write down all your codes and comments. It may look something like this.
#
# ![image.png](attachment:9d3bcd52-331b-4d11-9f9c-53829e84fee7.png)
#
# **Shell** is where you run the script, lets say in CMD. This is where you get the result of your code. It may look something like this.
#
# ![image.png](attachment:da56394d-5632-4606-9477-e874fbf5cd5e.png)

# %% [markdown]
# # The Need for Python in Business Analytics
# Python is all over the place, and it's finding application in the domain of web development, data science, RPA, artificial intelligence, and much more. Almost every industry right from healthcare, retail, finance, to manufacturing is using Python applications in one or the other form to improve their business efficiency. Its ability to store, access, and manipulate data has made it a darling for data science applications. The flexibility to access data and the simple coding syntax has made it one of the most popular programming language for business analytics applications.
#
# * **Relatively simple to learn:** When compared to other programming languages, some might say that Python is quite easy to learn. It has a relatively simple syntax and plenty of great learning resources.
#
# * **Huge community support:** Obviously, Python is very popular. That is why, when you run into some problem, there is a high possibility that someone had run into the same problem before. Therefore, you can always find help or maybe even a ready-to-use solution.
#
# * **Plenty of brilliant off-the-shelf analytical solutions (including libraries for ML/DL):**  Speaking about ready-to-use solutions, analysts are often used to working with such, compared to developers who are comfortable designing their own. That is, the existence of numerous great Python libraries for data analytics is a great benefit.

# %% [markdown]
# # Basics of Python
#
# ## 1. Expressions
# I believe that Mathematics is the key to solve all the universe's problem, though I am not a good mathematician. But even without being a good mathematician one can understand **Expressions** and its anatomy.
#
# Lets say Kushal has 2 Mangos and Divya has got 6, so total they have 8 mangoes. Now imagine you do not know the figures an only know them as X and Y mangos. Now if we try to add it we get:   **X + Y = 8**.
#
# We have seen these figures many a time right? These are called expressions.Simply put it expresses something. So what do we have here:
# * **X** & **Y** which are called **Variables**
# * **=** is known as the assignment operator as we assign or put something in somehere in the computer's memory space.
# * **8** is known as the constant/value. No any expression is complete without a constant.
#
# **Expressions:** An expression is a combination of literals, variables, and operators that Python evaluates to produce an object. Each operand can be any expression, perhaps within parentheses. For example, we can compose expressions like 4 * (x - 3) or 5 * x - 6 and Python will understand what we mean.
#
# These are just elementry maths.
# ## 2. Keywords/Reserved Words

# %% [markdown]
# We have some words in Python for which the language unerstands only something specific that is already being inbuild. Like if I say "I am hungry", one will understand that I am hungry and I want food, my body need something to consume, or perhaps some good *chole-kulchey*.
#
# Similarly in Python we have some words for which Python takes one and only one meaning that it is supposed to take. We cannot use those words anywhere anytime without making any sense. They cannot be variables or constants or anything other than what they are supposed to do and designed for. The list of words are given below.
#
# We can see them using the following command:
# ![image.png](attachment:4ea0d6ab-384d-4c88-9398-b7b031abbf11.png)

# %% [markdown]
# ## 3. Comments
#
# I know! Don't even think about it. No, its not any Facebook or Instagram stuffs. Its plain,smooth, healthy and simple *Comments*.
# Lets say I give you some gadget and tell you to do some stuff, how will you do if you do not even know what that gadget is for.  Like wise, **Comments** are used in Python, not just in Python but any programming lanuage to help the viewer or the user to understand what the piece of code is for, what does is do? This way codes are beautiful and as expressive as they can be. Below is a small example of comments in Python.
#
# ![image.png](attachment:0b6acfc5-c34f-416f-bed5-d8ce0a24d687.png)
#
# A comment in Python starts with the hash character, # , and extends to the end of the physical line. A hash character within a string value is not seen as a comment, though. To be precise, a comment can be written in three ways - entirely on its own line, next to a statement of code, and as a multi-line comment block. Follow the [Link](https://stackabuse.com/commenting-python-code/#:~:text=A%20comment%20in%20Python%20starts,a%20multi%2Dline%20comment%20block.) to get a better overview on *Comments*.

# %% [markdown]
# ## 4. Variable Names
# We don't like it if someone spell our name wrongly or mistakes in writing the spelling or something. Likewise in Python, we have names for *variables*. Yes, we name them, and they are very much like us, i.e. the names have rules that you need to follow.
#
# Officially, variable names in Python can be any length and can consist of uppercase and lowercase letters (A-Z, a-z), digits (0-9), and the underscore character (_). An additional restriction is that, although a variable name can contain digits, the first character of a variable name cannot be a digit.
# **Note:** Avoid using Reserved Keywords. Python won't like like it and will throw error.
#
# **Variables:** A variable is a name for an object reference. We use variables to keep track of changing values as a computation unfolds. We use diagrams like the one at right to show the binding of a variable to an object.

# %% [markdown]
# ## 5. Data Types
#
# Like we have positions and post for people working at a place, the same way Python has *data type* to distinguish various objects. For us, Humans, it is really simple to tell what is what, but for programming language it is not. Fortunately, Python is easier and it takes whatever we give him. So if we say: **x = 67** it wil take it as it is and again if we say: **x = 'ABC'** it will change to ABC. It is that simple.
#
# In Python we have the following basic data types:
# * **int :** Integers
# * **float :** Floating point number (numbers with decimal values)
# * **str :** String objects (abc, efg etc)
# * **bool:** Boolean values (0,1, TRUE, FALSE)
# * **fractions:** Fractional numbers
#
# ![image.png](attachment:c02b1c48-2f41-4ece-9122-6ca4f2e973da.png)
#
# Lets look at a few examples below:

# %%
# Integers

x = 123
y = 87
z = 5

print(x,y,z)    # "print" in Python is used to print anything.
print(type(x),type(y),type(z))     # "type" in Python is used to know the type of a variable or object.
# Out:
# 123 87 5
# <class 'int'> <class 'int'> <class 'int'>

# %% [markdown]
# **Note: Division:** In Python 3, the **/** operator has the same behavior as the floating-point division operator when both its operands are integers. In Python 2, the **/** operator has the same behavior as the floored division operator **//** when both its operands are integers. For example, 17 / 2 evaluates to 8.5 in Python 3 and to 8 in Python 2. For compatibility among Python versions, we do not use the **/** operator with two int operands in this booksite.

# %%
# Float
x = 123.45
y = 87.67
z = 5.3

print(x,y,z)
print(type(x),type(y),type(z))
# Out:
# 123.45 87.67 5.3
# <class 'float'> <class 'float'> <class 'float'>

# %%
# Strings: They are given inside quotes, it can be double or single i.e. ("") or ('').

x = 'Kushal'
y = 'Divya'
z = 'abc'

print(x,y,z)
print(type(x),type(y),type(z))
# Out:
# Kushal Divya abc
# <class 'str'> <class 'str'> <class 'str'>

# %%
# Boolean
x = True
y = False
z = 0
z1 = 1

print(x,y,z)
print(type(x),type(y),type(z),type(z1))
# Out:
# True False 0
# <class 'bool'> <class 'bool'> <class 'int'> <class 'int'>

# %% [markdown]
# **Note:**
# * a and b is True if both operands are True, and False if either is False.
# * a or b is False if both operands are False, and True if either is True.
# * not a is True if a is False, and False if a is True.

# %%
# Fractions : Fractions is a library in python which have to be imported.

from fractions import Fraction       #Importing Fraction library
x = Fraction(16, -10)

print(x)
print(type(x))

y = Fraction(16, 4)

print(y)
type(y)
print(type(y))

z = Fraction(7, 21) #  By default the value will be reduced to lowest granularity

print(z)
print(type(z))
# Out:
# -8/5
# <class 'fractions.Fraction'>
# 4
# <class 'fractions.Fraction'>
# 1/3
# <class 'fractions.Fraction'>

# %% [markdown]
# ## 6. Operators
# There are various operator in Python. They are nothing but symbols to denote some work that we want Python to do for us.

# %% [markdown]
# ### Assignment Operators
# Assignment operators are used in Python to assign values to variables.Lets say, **a = 5** is a simple assignment operator that assigns the value 5 on the right to the variable **'a'** on the left.There are various compound operators in Python like **a += 5** that adds to the variable and later assigns the same. It is equivalent to **a = a + 5**.
#
# * '=' : x = 5 equals to x = 5
# * '+=' : x += 5 equals to x + 5

# %% [markdown]
# ### Arithmatic Operaors:
#
# Arithmetic operators are used to perform mathematical operations like addition, subtraction, multiplication, etc.
#
#     * '+'     : Add two operands or unary plus
#     * '-'     : Subtract right operand from the left or unary minus
#     * "*"     : Multiply two operands
#     *  /      : Divide left operand by the right one (always results into float)
#     *  %      :  Modulus - remainder of the division of left operand by the right
#     *  //     : Floor division - division that results into whole number adjusted to the left in the number line
#     *  **     : Exponent - left operand raised to the power of right

# %% [markdown]
# ### Comparision Operator/ Relational Operators
#
# Comparison operators are used to compare values. It returns either True or False according to the condition.
#
#
# * **'>'** : Greater than - True if left operand is greater than the right
# * **<**   : Less than - True if left operand is less than the right
# * **==**  : Equal to - True if both operands are equal
# * **!=**  : Not equal to - True if operands are not equal
# * **'>='**: Greater than or equal to - True if left operand is greater than or equal to the right
# * **<=**  : Less than or equal to - True if left operand is less than or equal to the right

# %% [markdown]
# ### Logical Operators
#
# Logical operators are the **and, or, not** operators.
#
# * **and**  : True if both the operands are true
# * **or**   : True if either of the operands is true
# * **not**  : True if operand is false (complements the operand)

# %% [markdown]
# ### Bit-wise Operators
#
# Bitwise operators act on operands as if they were strings of binary digits. They operate bit by bit, hence the name. For example, **2** is **10** in *binary* and **7** is **111**. In the table below: Let **x = 10** *(0000 1010 in binary)* and **y = 4** *(0000 0100 in binary)*.
#
# * **&**    : Bitwise AND i.e. **x & y = 0** (0000 0000)
# * **|**    : Bitwise OR i.e. **x | y = 14** (0000 1110)
# * **~**    : Bitwise NOT i.e. **~x = -11** (1111 0101)
# * **^**    : Bitwise XOR i.e. **x ^ y = 14** (0000 1110)
# * **'>>'** : Bitwise right shift i.e. **x >> 2 = 2** (0000 0010)
# * **<<**   : Bitwise left shift i.e. **x << 2 = 40** (0010 1000)

# %% [markdown]
# ### Identity Operators
# The **is** and **is not** are the identity operators in Python. They are used to check if two values (or variables) are located on the same part of the memory. Two variables that are equal *does not imply that they are identical*.
#
# * **is :** True if the operands are identical (refer to the same object)
# * **is not :** True if the operands are not identical (do not refer to the same object)

# %% [markdown]
# ### Membership Operators
# **in** and **not in** are the membership operators in Python. They are used to test whether a value or variable is found in a **sequence (string, list, tuple, set and dictionary)**.
#
# * **in:** True if value/variable is found in the sequence
# * **not in :** True if value/variable is not found in the sequence
#
# **Note:** more on string, list, tuple, set and dictionary later in the journey.

# %% [markdown]
# ## 7. Python Input, Output and Import
# Python provides numerous built-in functions that are readily available to us at the Python prompt. Some of the functions like **input()** and **print()** are widely used for standard input and output operations respectively.
#
# * **print():** print(*objects, sep=' ', end='\n', file=sys.stdout, flush=False)
# * **input():** input([prompt]) , where prompt is optional
# * **import():** example: import math

# %%
# print()
print('This sentence is output to the screen')
a = 5
print('The value of a is', a)
# Out:
# This sentence is output to the screen
# The value of a is 5

# %% [markdown]
# #### Output Formatting
# Sometimes we would like to format our output to make it look attractive. This can be done by using the **str.format()** method. This method is visible to any string object.

# %%
x = 5; y = 10
print('The value of x is {} and y is {}'.format(x,y))
# Out:
# The value of x is 5 and y is 10

# %% [markdown]
# Here, the curly braces **{}** are used as placeholders. We can specify the order in which they are printed by using numbers (tuple, index) as shown below.

# %%
print('I love {0} and {1}'.format('bread','butter'))
print('I love {1} and {0}'.format('bread','butter'))
# Out:
# I love bread and butter
# I love butter and bread

# %%
#We can even use keyword arguments to format the string.
print('Hello {name}, {greeting}'.format(greeting = 'Goodmorning', name = 'John'))
# Out:
# Hello John, Goodmorning

# %% [markdown]
# #### Input
# Up until now, our programs were static. The value of variables was defined or hard coded into the source code.
# To allow flexibility, we might want to take the input from the user. In Python, we have the input() function to allow this. The syntax for input() is:
#
# * input([prompt]) :  where prompt is the string we wish to display on the screen. It is optional.

# %%
num = input('Enter a number: ') # The values taken will be sting always irrespective of what value you put
num
print('Hello {name}, {greeting}'.format(greeting = 'Goodmorning', name = input('Enter a Name:')) )
# Out:
# Enter a number:  87
# Enter a Name: Shank
# Hello Shank, Goodmorning

# %% [markdown]
# #### Import
# When our program grows bigger, it is a good idea to break it into different modules.A module is a file containing Python definitions and statements. Python modules have a filename and end with the extension .py.Definitions inside a module can be imported to another module or the interactive interpreter in Python. We use the import keyword to do this.

# %%
import math
print(math.pi)
# Out:
# 3.141592653589793

# %%
import sys
sys.path
# Out:
# ['C:\\Users\\shank\\Documents\\Python',
#  'C:\\Users\\shank\\anaconda3\\python38.zip',
#  'C:\\Users\\shank\\anaconda3\\DLLs',
#  'C:\\Users\\shank\\anaconda3\\lib',
#  'C:\\Users\\shank\\anaconda3',
#  '',
#  'C:\\Users\\shank\\anaconda3\\lib\\site-packages',
#  'C:\\Users\\shank\\anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\shank\\anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\shank\\anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\shank\\anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\shank\\.ipython']

# %% [markdown]
# ## 8. Type Conversion
# The process of converting the value of one data type (integer, string, float, etc.) to another data type is called type conversion. Python has two types of type conversion.
#
# ![image.png](attachment:0c34750f-0be1-4df8-97f0-5c1548584e9e.png)
# * Implicit Type Conversion
# * Explicit Type Conversion

# %% [markdown]
# #### Implicit Type Conversion
# In Implicit type conversion, Python automatically converts one data type to another data type. This process doesn't need any user involvement.Let's see an example where Python promotes the conversion of the lower data type (integer) to the higher data type (float) to avoid data loss.

# %%
num_int = 123
num_flo = 1.23

num_new = num_int + num_flo

print("datatype of num_int:",type(num_int))
print("datatype of num_flo:",type(num_flo))

print("Value of num_new:",num_new)
print("datatype of num_new:",type(num_new))
# Out:
# datatype of num_int: <class 'int'>
# datatype of num_flo: <class 'float'>
# Value of num_new: 124.23
# datatype of num_new: <class 'float'>

# %% [markdown]
# In the above program,
# We add two variables **num_int** and **num_flo**, storing the value in **num_new**.In the output, we can see the data type of **num_int** is an **integer** while the data type of **num_flo** is a **float**. Also, we can see the **num_new** has a **float** data type because Python always converts smaller data types to larger data types **to avoid the loss of data**.

# %% [markdown]
# #### Explicit Type Conversion
# In Explicit Type Conversion, users convert the data type of an object to required data type. We use the predefined functions like **int(), float(), str()**, etc to perform explicit type conversion.This type of conversion is also called **typecasting** because the user **casts (changes)** the data type of the objects.
#
# * Syntax : **"(required_datatype)(expression)"**

# %%
num_int = 123
num_str = "456"

print("Data type of num_int:",type(num_int))
print("Data type of num_str before Type Casting:",type(num_str))

num_str = int(num_str)
print("Data type of num_str after Type Casting:",type(num_str))

num_sum = num_int + num_str

print("Sum of num_int and num_str:",num_sum)
print("Data type of the sum:",type(num_sum))
# Out:
# Data type of num_int: <class 'int'>
# Data type of num_str before Type Casting: <class 'str'>
# Data type of num_str after Type Casting: <class 'int'>
# Sum of num_int and num_str: 579
# Data type of the sum: <class 'int'>

# %% [markdown]
# In the above program, we add **num_str** and **num_int** variable. We converted **num_str** from **string(higher)** to **integer(lower)** type using **int()** function to perform the addition.After converting **num_str** to an **integer value**, Python is able to add these two variables.We got the **num_sum value** and data type to be an **integer**.
#
# * **Key Points to Remember:**
#   * Type Conversion is the conversion of object from one data type to another data type.
#   * Implicit Type Conversion is automatically performed by the Python interpreter.
#   * Python avoids the loss of data in Implicit Type Conversion.
#   * Explicit Type Conversion is also called Type Casting, the data types of objects are converted using predefined functions by the user.
#   * In Type Casting, loss of data may occur as we enforce the object to a specific data type.

# %% [markdown]
# ## 9. Operator Precedence
# Given an expression we have usual rules of calculation like we foolow in mathematics which is called **BODMAS** or sometime **PEMDAS**. For python we have similary hierarchy. The following table lists all operators from highest precedence to lowest.
#
# ![image.png](attachment:6b361b86-ba63-4984-8847-71367424f5be.png)

# %% [markdown]
# ## 10. Identation
# Indentation in Python refers to the (spaces and tabs) that are used at the beginning of a statement. The statements with the same indentation belong to the same group called a suite.

# %%
# Example
if a==1:
    print(a)
    if b==2:
        print(b)
print('end')
# Out:
# end

# %% [markdown]
# In the above code, the first and last line of the statement is related to the same suite because there is no indentation in front of them. So after executing first "if statement", the Python interpreter will go into the next statement. If the condition is not true, it will execute the last line of the statement.

# %% [markdown]
# ## 11. Glossary
#
# * **Objects:** All data values in a Python program are represented by objects and relationships among objects. An object is an in-computer-memory representation of a value from a particular data type. Each object is characterized by its identity, type, and value.
#   * The identity uniquely identifies an object. You should think of it as the location in the computer's memory (or memory address) where the object is stored.
#   * The type of an object completely specifies its behavior — the set of values it might represent and the set of operations that can be performed on it.
#   * The value of an object is the data-type value that it represents.
#
# Each object stores one value; for example, an object of type int can store the value 1234 or the value 99 or the value 1333. Different objects may store the same value. For example, one object of type str might store the value 'hello', and another object of type str also might store the same value 'hello'. We can apply to an object any of the operations defined by its type (and only those operations). For example, we can multiply two int objects but not two str objects.
#
# * **Object references:** An object reference is nothing more than a concrete representation of the object's identity (the memory address where the object is stored). Python programs use object references either to access the object's value or to manipulate the object references themselves.
#
# * **Literals:** A literal is a Python-code representation of a data-type value. It creates an object with the specified value.
#
# * **Operators:** An operator is a Python-code representation of a data-type operation. For example, Python uses + and * to represent addition and multiplication for integers and floating-point numbers; Python uses and, or, and not to represent boolean operations; and so forth.
#
# * **Assignment statements:** An assignment statement is a directive to Python to bind the variable on the left side of the = operator to the object produced by evaluating the expression on the right side. For example, when we write c = a + b, we are expressing this action: "associate the variable c with the sum of the values associated with the variables a and b."

# %% [markdown]
# ## References:
#
# 1. [Introduction to Programming in Python](https://introcs.cs.princeton.edu/python/home/)
# 2. [Python for Everybody (PY4E)](https://www.py4e.com/)
# 3. [Think Python 2.0](https://greenteapress.com/thinkpython2/html/thinkpython2002.html)
# 4. [SciPy Lecture Notes](https://scipy-lectures.org/index.html)
# 5. [MATH20621 Programming with Python](https://personalpages.manchester.ac.uk/staff/stefan.guettel/py/)
# 6. [Introduction to Computer Science and Programming in Python](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-0001-introduction-to-computer-science-and-programming-in-python-fall-2016/index.htm)
# 7.[Dive Into Python 3](https://diveintopython3.net/table-of-contents.html#native-datatypes)
# 8. [Harvard University: CS]
